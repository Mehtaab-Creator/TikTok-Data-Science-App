# %% [markdown]
# # EXPLORATORY ANALYSIS

# %%
import pandas as pd

# %%
df = pd.read_json('trending_export.json')

# %%
df.head()
# Out:
#                     id                                               desc  \
# 0  6839416095586159616  Repost 😇 #catsoftiktok #viral #funny #cute #cu...
# 1  6915785138202758144  Wee #foryou #foryoupage #tiktok #wee #funny #d...
# 2  6869149203290000384  Our WHOLE Zoom class pranked our teacher 😂😂 (s...
# 3  6924780149560986624  Had to make sure momma was there #funny #fyp #...
# 4  7017118510044154880  Reply to @hankgreen1 @bunmousa not again #come...
#
#    createTime                                              video  \
# 0  1592425654  {'id': '6839416095586159878', 'height': 1024, ...
# 1  1610206707  {'id': '6915785138202758401', 'height': 1024, ...
# 2  1599348438  {'id': '6869149203290000645', 'height': 1024, ...
# 3  1612301030  {'id': '6924780149560986886', 'height': 1082, ...
# 4  1633800220  {'id': '7017118510044155142', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6832141644758975494', 'uniqueId': 'bri...
# 1  {'id': '6910135297574568961', 'uniqueId': 'fun...
# 2  {'id': '6734403205457642502', 'uniqueId': 'sam...
# 3  {'id': '6924776941027329029', 'uniqueId': 'ban...
# 4  {'id': '6635415767817043974', 'uniqueId': 'xth...
#
#                                                music  \
# 0  {'id': '6839416100652894982', 'title': 'origin...
# 1  {'id': '6901784069365975809', 'title': '.....W...
# 2  {'id': '6840839890826038022', 'title': 'M to t...
# 3  {'id': '6924780218162875141', 'title': 'origin...
# 4  {'id': '6746993352891189249', 'title': 'Monkey...
#
#                                           challenges  \
# 0  [{'id': '1601336200518658', 'title': 'catsofti...
# 1  [{'id': '42164', 'title': 'foryou', 'desc': ''...
# 2  [{'id': '42164', 'title': 'foryou', 'desc': ''...
# 3  [{'id': '5424', 'title': 'funny', 'desc': 'Oh,...
# 4  [{'id': '7888', 'title': 'comedy', 'desc': '',...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 36800000, 'shareCount': 2800000,...  {'duetFromId': '0'}
# 1  {'diggCount': 19800000, 'shareCount': 1300000,...  {'duetFromId': '0'}
# 2  {'diggCount': 19200000, 'shareCount': 431300, ...  {'duetFromId': '0'}
# 3  {'diggCount': 18800000, 'shareCount': 391900, ...  {'duetFromId': '0'}
# 4  {'diggCount': 18700000, 'shareCount': 388200, ...  {'duetFromId': '0'}
#
#    originalItem  ...                                        authorStats  \
# 0         False  ...  {'followingCount': 562, 'followerCount': 32000...
# 1         False  ...  {'followingCount': 51, 'followerCount': 500000...
# 2         False  ...  {'followingCount': 70, 'followerCount': 790000...
# 3         False  ...  {'followingCount': 66, 'followerCount': 150000...
# 4         False  ...  {'followingCount': 1385, 'followerCount': 7600...
#
#   privateItem  duetEnabled  stitchEnabled  shareEnabled   isAd  duetDisplay  \
# 0       False        False           True          True  False            0
# 1       False         True           True          True  False            0
# 2       False         True           True          True  False            0
# 3       False        False          False          True  False            0
# 4       False        False          False          True  False            0
#
#    stitchDisplay                                     stickersOnItem  \
# 0              0                                                NaN
# 1              0                                                NaN
# 2              0  [{'stickerType': 4, 'stickerText': ['We did th...
# 3              0                                                NaN
# 4              0  [{'stickerType': 4, 'stickerText': ['Did you s...
#
#   effectStickers
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Create helper function to process data

# %%
import json

# %%
#Loads json data file
with open('trending_export.json', 'r') as f:
    data = json.load(f)

# %%
nested_values = ['video', 'author','music','shareCover','challenges','duetInfo','textExtra', 'stickersOnItem','stats','authorStats']
skip_values = ['shareCover','challenges','duetInfo','textExtra', 'stickersOnItem']

# %%
#create blank dictionary
flattened_data = {}
#looping through each video
for idx, value in enumerate(data):
    flattened_data[idx] = {}
    #looping through each property in each video
    for prop_idx, prop_value in value.items():
        #check if nested
        if prop_idx in nested_values:
            if prop_idx in skip_values:
                pass
            else:
                #loop through each nested property
                for nested_idx, nested_value in prop_value.items():
                    flattened_data[idx][prop_idx+'_'+nested_idx] = nested_value  
        #if its not nested, add it back to the flattened dictionary        
        else:
            flattened_data[idx][prop_idx] = prop_value

# %%
flattened_data[0]
# Out:
# {'id': '6839416095586159878',
#  'desc': 'Repost 😇 #catsoftiktok #viral #funny #cute #cutness #foryoupage',
#  'createTime': 1592425654,
#  'video_id': '6839416095586159878',
#  'video_height': 1024,
#  'video_width': 576,
#  'video_duration': 13,
#  'video_ratio': '720p',
#  'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/80a7eece06774b96ae8b68df2fb524b2?x-expires=1649566800&x-signature=9usebZbbB1dIPl979o7YfyWDcGY%3D',
#  'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/da52d1bf0a1d4574830cce5e6fccbbfc_1592425657?x-expires=1649566800&x-signature=9SrhyDMK9uVWkqWM18VeWEHhH1w%3D',
#  'video_dynamicCover': 'https://p77-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/8686754c69594cbd911c685c8f788769_1592425656?x-expires=1649566800&x-signature=bS9LRaNhJVwDgcTjxtxk4Pqyah8%3D',
#  'video_playAddr': 'https://v16-webapp.tiktok.com/cae396f51b2f38553a2167f2e7f14946/62526c6c/video/tos/useast2a/tos-useast2a-ve-0068c004/2362532506c24a66be8a02a69273732d/?a=1988&br=2652&bt=1326&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=eXd.6H1pMyq8ZNSGBwe2NQaeyl7Gb&l=202204092334240102230780221A27ACB0&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2tmOHM1Ojc6dTMzMzczM0ApZDpnZmVmM2QzNzM3OmVmaWdeYm1nLjE0bWlfLS1iMTZzczIuNTZeYDNgNTM2XmFhMDU6Yw%3D%3D&vl=&vr=',
#  'video_downloadAddr': 'https://v16-webapp.tiktok.com/cae396f51b2f38553a2167f2e7f14946/62526c6c/video/tos/useast2a/tos-useast2a-ve-0068c004/2362532506c24a66be8a02a69273732d/?a=1988&br=2652&bt=1326&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=eXd.6H1pMyq8ZNSGBwe2NQaeyl7Gb&l=202204092334240102230780221A27ACB0&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2tmOHM1Ojc6dTMzMzczM0ApZDpnZmVmM2QzNzM3OmVmaWdeYm1nLjE0bWlfLS1iMTZzczIuNTZeYDNgNTM2XmFhMDU6Yw%3D%3D&vl=&vr=',
#  'video_shareCover': ['',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/da52d1bf0a1d4574830cce5e6fccbbfc_1592425657~tplv-tiktok-play.jpeg?x-expires=1650150000&x-signature=vmu73TocBBUB7MPOmL4sr2bSE5Q%3D',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/da52d1bf0a1d4574830cce5e6fccbbfc_1592425657~tplv-tiktokx-share-play.jpeg?x-expires=1650150000&x-signature=1030kbjWgMA0QKGpVrImBoc9lMo%3D'],
#  'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/80a7eece06774b96ae8b68df2fb524b2?x-expires=1649566800&x-signature=9usebZbbB1dIPl979o7YfyWDcGY%3D',
#  'video_bitrate': 1358289,
#  'video_encodedType': 'normal',
#  'video_format': 'mp4',
#  'video_videoQuality': 'normal',
#  'video_encodeUserTag': '',
#  'video_codecType': 'h264',
#  'video_definition': '720p',
#  'author_id': '6832141644758975494',
#  'author_uniqueId': 'britishpromise.cats',
#  'author_nickname': 'British Promise Cats',
#  'author_avatarThumb': 'https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=5X9RBTbTcNER8SvaBi9hN8kjbqY%3D',
#  'author_avatarMedium': 'https://p16-sign-sg.tiktokcdn.com/aweme/720x720/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=ldrZu8lqEQyAvbcw7KYVGAh1lCw%3D',
#  'author_avatarLarger': 'https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=gaiVL%2FD4e9F9dy6B1oM9pXTDwAA%3D',
#  'author_signature': 'You all are beautiful butterflies🦋\n\nDm me on insta😄',
#  'author_verified': False,
#  'author_secUid': 'MS4wLjABAAAAwT5O-Y58XnBVqJBX1RFdGYOQCAkKfaiQ-SCaErKOs5AmAULYXZNG96CvmxhnR0aw',
#  'author_secret': False,
#  'author_ftc': False,
#  'author_relation': 0,
#  'author_openFavorite': False,
#  'author_commentSetting': 0,
#  'author_duetSetting': 0,
#  'author_stitchSetting': 0,
#  'author_privateAccount': False,
#  'author_isADVirtual': False,
#  'music_id': '6839416100652894982',
#  'music_title': 'origineel geluid',
#  'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6839416075390552838.mp3',
#  'music_coverThumb': 'https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=5X9RBTbTcNER8SvaBi9hN8kjbqY%3D',
#  'music_coverMedium': 'https://p16-sign-sg.tiktokcdn.com/aweme/720x720/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=ldrZu8lqEQyAvbcw7KYVGAh1lCw%3D',
#  'music_coverLarge': 'https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tos-alisg-avt-0068/e57097cc1c4812f626f43c8053e9b7c5.jpeg?x-expires=1649631600&x-signature=gaiVL%2FD4e9F9dy6B1oM9pXTDwAA%3D',
#  'music_authorName': 'British Promise Cats',
#  'music_original': True,
#  'music_duration': 12,
#  'music_album': '',
#  'stats_diggCount': 36800000,
#  'stats_shareCount': 2800000,
#  'stats_commentCount': 472200,
#  'stats_playCount': 294500000,
#  'originalItem': False,
#  'officalItem': False,
#  'secret': False,
#  'forFriend': False,
#  'digged': False,
#  'itemCommentStatus': 0,
#  'showNotPass': False,
#  'vl1': False,
#  'itemMute': False,
#  'authorStats_followingCount': 562,
#  'authorStats_followerCount': 3200000,
#  'authorStats_heartCount': 47200000,
#  'authorStats_videoCount': 107,
#  'authorStats_diggCount': 35700,
#  'authorStats_heart': 47200000,
#  'privateItem': False,
#  'duetEnabled': False,
#  'stitchEnabled': True,
#  'shareEnabled': True,
#  'isAd': False,
#  'duetDisplay': 0,
#  'stitchDisplay': 0}

# %%
type(flattened_data)
# Out:
# dict

# %% [markdown]
# # Test out output

# %%
df_test = pd.DataFrame.from_dict(flattened_data, orient = 'index')

# %%
df_test
# Out:
#                      id                                               desc  \
# 0   6839416095586159878  Repost 😇 #catsoftiktok #viral #funny #cute #cu...
# 1   6915785138202758401  Wee #foryou #foryoupage #tiktok #wee #funny #d...
# 2   6869149203290000645  Our WHOLE Zoom class pranked our teacher 😂😂 (s...
# 3   6924780149560986886  Had to make sure momma was there #funny #fyp #...
# 4   7017118510044155142  Reply to @hankgreen1 @bunmousa not again #come...
# 5   6974585687798500613  Wow!! #comedy #funny #mickeymouse #mickey #odd...
# 6   6910202622200909058  @Dasha 님과 #이어찍기 #추천 #fyp #viral #funny #xyzbca...
# 7   6958603581675031814                      #fyp #meme #funny #meme #vine
# 8   6911397395402165505  Wee 😂 #foryou #foryoupage #4u #tiktok #animals...
# 9   6866927712745901318                It threw up😹😹😹#cat #petlifes #funny
# 10  6918375185200598273  @❤️Sasha&Vanya&Roma❤️ 님과 #이어찍기  #추천 #fyp #vira...
# 11  6991131155013668102  Wait / Go #fypシ #charlie #wait #go #funny #cut...
# 12  6987393714888985862  Android vs Apple 😁 #mercuri_88 #littlebrother ...
# 13  6925644731653393670  Uhhh, she isn’t robbing anyone with that mask....
# 14  6744084223445044485  The last guy tho 😂😂😂 #lol #funny #foryou #fory...
# 15  7062053199888338222  Still gets me every time🤣 #gheefunny #mcdonald...
# 16  7032432940156210478  I swear these baby’s be grown af lol this vide...
# 17  6911421504634850565  This is the best gift idea I’ve ever had. #gre...
# 18  6957730468200533253  Can you guess what happened next😬🤣 @montyydm_t...
# 19  7020056546709114117  I went to the bathroom and came back and almos...
# 20  6821608032351374597  IM CRYIN @collinskitchens  #neverfitin #acnh #...
# 21  6922100922717965569  #fyp #tourettes #foryou #tourettesawareness #l...
# 22  6956679165605055749     #fyp #foryoupage #foryou #nowlookatthis #funny
# 23  6820840648917159174  Our WHOLE class pranked our teacher Pt.12 😂😂 (...
# 24  7060785845707607301  Poor boy! 😅🥺 #funny #viral #parentsoftiktok #t...
# 25  6984893201412820229  Dommy was getting lunch at school. #funny #dad...
# 26  6931494638096305413  MICHAEL J😎😜#michaeljackson #character #parati ...
# 27  7041303516341849391  A tragic back story  @traveler9314 #cats #cats...
# 28  7040763278565461250  Splash Us! 🤣 #funny #challenge #rain #wet #mak...
# 29  6944773880707943686    this trend but GYM version 😂 #foryoupage #funny
#
#     createTime             video_id  video_height  video_width  \
# 0   1592425654  6839416095586159878          1024          576
# 1   1610206707  6915785138202758401          1024          576
# 2   1599348438  6869149203290000645          1024          576
# 3   1612301030  6924780149560986886          1082          576
# 4   1633800220  7017118510044155142          1024          576
# 5   1623897279  6974585687798500613           576          660
# 6   1608906926  6910202622200909058          1024          576
# 7   1620176163  6958603581675031814          1024          576
# 8   1609185107  6911397395402165505           756          576
# 9   1598831210  6866927712745901318          1024          576
# 10  1610809749  6918375185200598273          1024          576
# 11  1627749568  6991131155013668102          1024          576
# 12  1626879380  6987393714888985862          1024          576
# 13  1612502352  6925644731653393670           960          540
# 14  1570229474  6744084223445044485          1280          720
# 15  1644262393  7062053199888338222          1024          576
# 16  1637365889  7032432940156210478          1024          576
# 17  1609190731  6911421504634850565          1024          576
# 18  1619972866  6957730468200533253          1024          576
# 19  1634484285  7020056546709114117          1024          576
# 20  1588279391  6821608032351374597          1024          576
# 21  1611677216  6922100922717965569          1024          576
# 22  1619728091  6956679165605055749          1024          576
# 23  1588100720  6820840648917159174          1024          576
# 24  1643967317  7060785845707607301           848          464
# 25  1626297183  6984893201412820229          1024          576
# 26  1613864371  6931494638096305413          1024          576
# 27  1639431236  7041303516341849391          1024          576
# 28  1639305447  7040763278565461250          1024          576
# 29  1616956175  6944773880707943686          1024          576
#
#     video_duration video_ratio  \
# 0               13        720p
# 1                7        720p
# 2               14        720p
# 3               10        720p
# 4               16        720p
# 5               13        720p
# 6               10        720p
# 7               11        720p
# 8                7        720p
# 9                6        720p
# 10              18        720p
# 11              16        720p
# 12              10        720p
# 13              10        720p
# 14              18        720p
# 15              42        720p
# 16              60        720p
# 17              57        720p
# 18              19        720p
# 19               9        720p
# 20              11        720p
# 21              59        720p
# 22              10        720p
# 23              19        720p
# 24               8        480p
# 25              47        720p
# 26              16        720p
# 27              24        720p
# 28              32        720p
# 29              47        720p
#
#                                           video_cover  \
# 0   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1   https://p77-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2   https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 3   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4   https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 5   https://p77-sign-va.tiktokcdn.com/obj/tos-mali...
# 6   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 7   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 8   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 9   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 10  https://p77-sign-sg.tiktokcdn.com/obj/tos-alis...
# 11  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 12  https://p77-sign-va.tiktokcdn.com/tos-maliva-p...
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 15  https://p16-sign.tiktokcdn-us.com/obj/tos-usea...
# 16  https://p16-sign.tiktokcdn-us.com/obj/tos-usea...
# 17  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 19  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 20  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 21  https://p77-sign-sg.tiktokcdn.com/obj/tos-alis...
# 22  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 23  https://p77-sign-va-lite.tiktokcdn.com/obj/tos...
# 24  https://p77-sign-va-lite.tiktokcdn.com/obj/tos...
# 25  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 26  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 27  https://p16-sign.tiktokcdn-us.com/obj/tos-usea...
# 28  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 29  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                     video_originCover  ...  \
# 0   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 1   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 2   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 3   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 4   https://p77-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 5   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 6   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 7   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 8   https://p77-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 9   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 10  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 11  https://p77-sign-va-lite.tiktokcdn.com/obj/tos...  ...
# 12  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 15  https://p19-sign.tiktokcdn-us.com/obj/tos-usea...  ...
# 16  https://p16-sign.tiktokcdn-us.com/obj/tos-usea...  ...
# 17  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 19  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 20  https://p77-sign-va-lite.tiktokcdn.com/obj/tos...  ...
# 21  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 22  https://p77-sign-va-lite.tiktokcdn.com/obj/tos...  ...
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 24  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 25  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 26  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 27  https://p19-sign.tiktokcdn-us.com/obj/tos-usea...  ...
# 28  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 29  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
#
#    authorStats_diggCount authorStats_heart privateItem duetEnabled  \
# 0                  35700          47200000       False       False
# 1                   1280          86600000       False        True
# 2                    220         306800000       False        True
# 3                   3418          21800000       False       False
# 4                  23500         286000000       False       False
# 5                   8897         174500000       False        True
# 6                   6000        1200000000       False        True
# 7                   9099          35000000       False        True
# 8                   1280          86600000       False        True
# 9                    439          58400000       False        True
# 10                  6000        1200000000       False        True
# 11                   109          34300000       False        True
# 12                 24600         337400000       False       False
# 13                 22400          12800000       False        True
# 14                   220         306800000       False        True
# 15                 10100          36500000       False        True
# 16                  4680          12500000       False        True
# 17                 21400          40000000       False        True
# 18                  3374         147900000       False        True
# 19                   843          25900000       False        True
# 20                  1279          15000000       False        True
# 21                  4268          72400000       False       False
# 22                  1016          11300000       False        True
# 23                   220         306800000       False       False
# 24                   136          22900000       False        True
# 25                   198          75800000       False        True
# 26                  3707          13400000       False        True
# 27                  4094         270400000       False        True
# 28                   396          57100000       False       False
# 29                 63800         129000000       False        True
#
#    stitchEnabled  shareEnabled   isAd duetDisplay stitchDisplay  \
# 0           True          True  False           0             0
# 1           True          True  False           0             0
# 2           True          True  False           0             0
# 3          False          True  False           0             0
# 4          False          True  False           0             0
# 5           True          True  False           0             0
# 6           True          True  False           0             0
# 7           True          True  False           0             0
# 8           True          True  False           0             0
# 9           True          True  False           0             0
# 10          True          True  False           0             0
# 11          True          True  False           0             0
# 12         False          True  False           0             0
# 13          True          True  False           0             0
# 14          True          True  False           0             0
# 15          True          True  False           0             0
# 16          True          True  False           0             0
# 17          True          True  False           0             0
# 18          True          True  False           0             0
# 19          True          True  False           0             0
# 20          True          True  False           0             0
# 21         False          True  False           0             0
# 22          True          True  False           0             0
# 23         False          True  False           0             0
# 24          True          True  False           0             0
# 25          True          True  False           0             0
# 26          True          True  False           0             0
# 27          True          True  False           0             0
# 28         False          True  False           0             0
# 29          True          True  False           0             0
#
#                                        effectStickers
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [{'name': '타임스캔', 'ID': '913402'}, {'name': '얼...
# 11                                                NaN
# 12              [{'name': 'Stupido', 'ID': '368075'}]
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 77 columns]
